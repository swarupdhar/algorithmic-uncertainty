# %% [markdown]
# ### Prepare the dataset
#
# I've made it a little smaller

# %%
import numpy as np
import pandas as pd

import fatf.utils.data.datasets as fatf_datasets
import fatf.utils.models as fatf_models

import fatf.fairness.predictions.measures as fatf_pfm

import fatf.transparency.predictions.counterfactuals as fatf_cf

import sys
sys.path.append("../../src")
# %load_ext autoreload
# %autoreload 2


from project import rf_models, preprocessing


df = pd.read_csv("../../data/initial_custody_2017_gsprs.csv", low_memory=False)


df = df[df["race"] != 'A'] # Drop Asian

#df = df[df["race"] != 'H'] # Drop Hispanic

df = df[df["race"] != 'I'] # Drop Indian

df = df[df["race"] != 'O'] # Drop Other

def label_age (row):
    if row['date_of_birth'] < 19720000 :
        return 2 #old
    elif row['date_of_birth'] < 19960000:
        return 1 #middle
    else: 
        return 0 #young 


df['age_cat'] = df.apply(lambda row: label_age(row), axis=1)





def hi_lo_ic(row):
    if row['ic_custdy_level'] < 4:
        return 0 #low
    else: 
        return 1 #high

df['cl_cat'] = df.apply(lambda row: hi_lo_ic(row), axis=1)



#print(df["ic_custdy_level"])
# preprocessing
data = preprocessing.preprocess_input_vars(df)

data = data.convert_dtypes(infer_objects=True, convert_string=True,
      convert_integer=True, convert_boolean=True, convert_floating=True)

data = data[data["ic_custdy_level"] > 1]

#print(data["race"])
census_names =     [
        "gender_female",
        "age_cat",
        "race",
        "off_1_prs_max",
        "off_1_gs_max",
        "prior_commits",
        "ic_institut_adj",
        "cl_cat"
    ]

data = data[
    [
        "gender_female",
        "age_cat",
        "race",
        "off_1_prs_max",
        "off_1_gs_max",
        "prior_commits",
        "ic_institut_adj",
        "cl_cat"
    ]
]
data = data.dropna()
# Out:
# 21-Aug-28 16:27:49 fatf.utils.array.tools INFO     Using numpy's numpy.lib.recfunctions.structured_to_unstructured as fatf.utils.array.tools.structured_to_unstructured and fatf.utils.array.tools.structured_to_unstructured_row.

# %%
data['off_1_gs_max'].describe()
# Out:
# count    13722.000000
# mean        11.777146
# std          3.073932
# min          1.000000
# 25%         10.000000
# 50%         12.000000
# 75%         14.000000
# max         15.000000
# Name: off_1_gs_max, dtype: float64

# %% [markdown]
# ### Convert data to a dictionary

# %%
X = data.drop("cl_cat", axis=1)

xx = X.to_records(index=False)

Y = data["cl_cat"]

dtypes = [('gender_female','i8'),
          ('age_cat','i8'),
          ('race','i8'),
          ('off_1_prs_max','f8'),
          ('off_1_gs_max','i8'),
          ('prior_commits','i8'),
          ('ic_institut_adj','i8')]

ic_data = {}

# %%
data_array = np.array(xx, dtype = dtypes)
data_array
# Out:
# array([(0, 2, 0, 4., 15,  1, 3), (0, 2, 0, 4., 14, 18, 2),
#        (0, 2, 0, 3., 14,  2, 2), ..., (0, 1, 2, 2.,  9,  3, 5),
#        (0, 2, 0, 3.,  5, 11, 2), (0, 1, 2, 3.,  8,  5, 2)],
#       dtype=[('gender_female', '<i8'), ('age_cat', '<i8'), ('race', '<i8'), ('off_1_prs_max', '<f8'), ('off_1_gs_max', '<i8'), ('prior_commits', '<i8'), ('ic_institut_adj', '<i8')])

# %%
ic_data['data'] = data_array
ic_data['target'] = np.array(Y.values, dtype='i4')
ic_data['target_names'] = ['low','high']
ic_data['feature_names'] = ['gender_female','age_cat','race','off_1_prs_max','off_1_gs_max','prior_commits','ic_instit_adj']

# %%
ic_X = ic_data['data']


ic_y = ic_data['target']
ic_feature_names = ic_data['feature_names']
ic_class_names = ic_data['target_names']

# %%
# Map target indices to target names
ic_y = np.array([ic_class_names[i] for i in ic_y], dtype='str')

# %%
unique_identifiers = []
columns_to_keep = [i for i in ic_X.dtype.names if i not in unique_identifiers]
#
ic_X = ic_X[columns_to_keep]
ic_feature_names = [i for i in ic_feature_names if i not in unique_identifiers]

# %%
print(ic_X)
# Out:
# [(0, 2, 0, 4., 15,  1, 3) (0, 2, 0, 4., 14, 18, 2)
#  (0, 2, 0, 3., 14,  2, 2) ... (0, 1, 2, 2.,  9,  3, 5)
#  (0, 2, 0, 3.,  5, 11, 2) (0, 1, 2, 3.,  8,  5, 2)]

# %%
#Train a model
clf = fatf_models.KNN()
clf.fit(ic_X, ic_y)

# %% [markdown]
# ### Check for counterfactuals

# %%
# Select a data point to evaluate its counterfactual fairness
data_point_index = 1124
data_point = ic_X[data_point_index]
data_point_y = ic_y[data_point_index]

# Select a set of protected features
protected_features = ['gender_female', 'age_cat','race']

# Print out the protected features
assert protected_features, 'The protected features list cannot be empty.'
person = ' is' if len(protected_features) == 1 else 's are'
print('The following fautre{} considered protected:'.format(person))
for feature_name in protected_features:
    print('    * "{}".'.format(feature_name))

# Print the instance
print('\nEvaluating counterfactual fairness of a data point (index {}) of '
      'class *{}* with the following features:'.format(data_point_index,
                                                       data_point_y))
for feature_name in data_point.dtype.names:
    print('    * The feature *{}* has value: {}.'.format(
        feature_name, data_point[feature_name]))
# Out:
# The following fautres are considered protected:
#     * "gender_female".
#     * "age_cat".
#     * "race".
#
# Evaluating counterfactual fairness of a data point (index 1124) of class *high* with the following features:
#     * The feature *gender_female* has value: 0.
#     * The feature *age_cat* has value: 1.
#     * The feature *race* has value: 0.
#     * The feature *off_1_prs_max* has value: 2.0.
#     * The feature *off_1_gs_max* has value: 12.
#     * The feature *prior_commits* has value: 1.
#     * The feature *ic_institut_adj* has value: 4.

# %%
data_point_index = 1
data_point = ic_X[data_point_index]
data_point_y = ic_y[data_point_index]
cfs, cfs_distances, cfs_classes = fatf_pfm.counterfactual_fairness(
    instance=data_point,
    protected_feature_indices=protected_features,
    model=clf,
    default_numerical_step_size=.5,
    dataset=ic_X)
print(cfs)
# Out:
# [(0. , 1.5, 1. , 4., 14, 18, 2) (0. , 2. , 1.5, 4., 14, 18, 2)
#  (0.5, 2. , 1. , 4., 14, 18, 2)]

# %%
ct = 0
for ii in range(1000):
    print("=====================================\nii =", ii)
    data_point_index = ii
    data_point = ic_X[data_point_index]
    data_point_y = ic_y[data_point_index]
    cfs, cfs_distances, cfs_classes = fatf_pfm.counterfactual_fairness(
        instance=data_point,
        protected_feature_indices=protected_features,
        model=clf,
        default_numerical_step_size=1,
        dataset=ic_X)
    #print(cfs)
    if len(cfs) > 0:
        ct +=1
        cfs_text = fatf_cf.textualise_counterfactuals(
            data_point,
            cfs,
            instance_class=data_point_y,
            counterfactuals_distances=cfs_distances,
            counterfactuals_predictions=cfs_classes)
        print('\n{}'.format(cfs_text))    
print(ct)
# Out:
# =====================================
# ii = 0
# =====================================
# ii = 1
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 18, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 2
#
# Instance (of class *low*):
# (0, 2, 0, 3., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
# =====================================
# ii = 3
# =====================================
# ii = 4
#
# Instance (of class *low*):
# (0, 2, 2, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 5
#
# Instance (of class *low*):
# (0, 2, 2, 3., 9, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 6
# =====================================
# ii = 7
#
# Instance (of class *low*):
# (0, 2, 0, 4., 14, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
# =====================================
# ii = 8
#
# Instance (of class *low*):
# (0, 2, 0, 4., 14, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 9
#
# Instance (of class *low*):
# (0, 2, 2, 3., 14, 5, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
# =====================================
# ii = 10
# =====================================
# ii = 11
# =====================================
# ii = 12
#
# Instance (of class *high*):
# (0, 2, 2, 1., 14, 4, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *low*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 13
#
# Instance (of class *low*):
# (0, 2, 2, 2., 6, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 14
#
# Instance (of class *high*):
# (0, 2, 2, 3., 13, 10, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 4.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 15
# =====================================
# ii = 16
#
# Instance (of class *high*):
# (0, 2, 2, 1., 14, 8, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 17
#
# Instance (of class *high*):
# (0, 2, 2, 1., 12, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 18
# =====================================
# ii = 19
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 20
# =====================================
# ii = 21
# =====================================
# ii = 22
#
# Instance (of class *low*):
# (0, 2, 0, 4., 12, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 23
# =====================================
# ii = 24
# =====================================
# ii = 25
#
# Instance (of class *high*):
# (0, 2, 2, 4., 6, 6, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 26
# =====================================
# ii = 27
# =====================================
# ii = 28
# =====================================
# ii = 29
#
# Instance (of class *low*):
# (0, 2, 0, 2., 12, 4, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 30
# =====================================
# ii = 31
# =====================================
# ii = 32
# =====================================
# ii = 33
#
# Instance (of class *low*):
# (0, 2, 2, 2., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 34
#
# Instance (of class *low*):
# (0, 2, 2, 3., 11, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 35
# Instance (of class *low*):
# (0, 2, 2, 3., 14, 6, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 4.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 36
# =====================================
# ii = 37
#
# Instance (of class *low*):
# (0, 2, 2, 3., 14, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 38
#
# Instance (of class *high*):
# (0, 2, 2, 4., 9, 3, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 39
#
# Instance (of class *low*):
# (0, 2, 2, 4., 13, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 40
# =====================================
# ii = 41
# =====================================
# ii = 42
# =====================================
# ii = 43
# =====================================
# ii = 44
#
# Instance (of class *high*):
# (0, 2, 0, 4., 7, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 45
#
# Instance (of class *high*):
# (0, 2, 0, 4., 12, 12, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 46
# =====================================
# ii = 47
#
# Instance (of class *high*):
# (0, 2, 0, 4., 12, 6, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 48
# =====================================
# ii = 49
# =====================================
# ii = 50
# =====================================
# ii = 51
# =====================================
# ii = 52
# =====================================
# ii = 53
#
# Instance (of class *low*):
# (0, 2, 2, 4., 14, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *low*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 54
# =====================================
# ii = 55
#
# Instance (of class *low*):
# (1, 2, 0, 0.5, 14, 0, 5)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *gender_female*: *1* -> *0*
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 56
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 5, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 57
# =====================================
# ii = 58
# =====================================
# ii = 59
# =====================================
# ii = 60
#
# Instance (of class *low*):
# (0, 2, 2, 3., 14, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 61
#
# Instance (of class *high*):
# (0, 2, 2, 4., 7, 3, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
# =====================================
# ii = 62
# =====================================
# ii = 63
#
# Instance (of class *low*):
# (0, 2, 0, 3., 7, 10, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 64
#
# Instance (of class *low*):
# (0, 2, 2, 1., 12, 5, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 65
#
# Instance (of class *high*):
# (0, 2, 2, 4., 14, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 66
# =====================================
# ii = 67
# =====================================
# ii = 68
#
# Instance (of class *low*):
# (0, 2, 2, 2., 7, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 4.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 69
#
# Instance (of class *low*):
# (0, 2, 0, 1., 11, 8, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 70
# =====================================
# ii = 71
#
# Instance (of class *low*):
# (0, 2, 2, 3., 15, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 72
# =====================================
# ii = 73
# =====================================
# ii = 74
# =====================================
# ii = 75
# =====================================
# ii = 76
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 5, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 77
# =====================================
# ii = 78
#
# Instance (of class *low*):
# (0, 2, 0, 4., 12, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 79
# =====================================
# ii = 80
# =====================================
# ii = 81
# =====================================
# ii = 82
#
# Instance (of class *low*):
# (0, 2, 0, 4., 12, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 83
# =====================================
# ii = 84
#
# Instance (of class *high*):
# (0, 2, 0, 4., 12, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 85
#
# Instance (of class *high*):
# (0, 2, 0, 4., 12, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 86
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 87
#
# Instance (of class *low*):
# (0, 2, 0, 3., 9, 6, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 88
#
# Instance (of class *low*):
# (0, 2, 2, 4., 12, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
# =====================================
# ii = 89
#
# Instance (of class *high*):
# (0, 2, 0, 4., 12, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 90
# =====================================
# ii = 91
# =====================================
# ii = 92
#
# Instance (of class *low*):
# (0, 2, 2, 3., 7, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
# =====================================
# ii = 93
# =====================================
# ii = 94
#
# Instance (of class *high*):
# (0, 2, 0, 4., 9, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 95
# =====================================
# ii = 96
#
# Instance (of class *high*):
# (0, 2, 2, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 97
#
# Instance (of class *high*):
# (0, 2, 2, 3., 14, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 98
#
# Instance (of class *low*):
# (0, 2, 2, 4., 12, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 99
# =====================================
# ii = 100
#
# Instance (of class *low*):
# (0, 2, 2, 3., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 4.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 101
# =====================================
# ii = 102
#
# Instance (of class *high*):
# (0, 2, 0, 2., 14, 1, 4)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 103
# =====================================
# ii = 104
# =====================================
# ii = 105
# =====================================
# ii = 106
# =====================================
# ii = 107
# =====================================
# ii = 108
# =====================================
# ii = 109
#
# Instance (of class *high*):
# (0, 2, 2, 3., 14, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 110
#
# Instance (of class *low*):
# (0, 2, 0, 3., 14, 7, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 111
#
# Instance (of class *low*):
# (0, 2, 0, 4., 14, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 112
# =====================================
# ii = 113
# =====================================
# ii = 114
#
# Instance (of class *high*):
# (0, 2, 1, 1., 12, 10, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *1* -> *0*
# =====================================
# ii = 115
# =====================================
# ii = 116
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 117
# =====================================
# ii = 118
#
# Instance (of class *low*):
# (0, 2, 2, 0.5, 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
# =====================================
# ii = 119
#
# Instance (of class *low*):
# (0, 1, 1, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *1* -> *0*
# =====================================
# ii = 120
#
# Instance (of class *low*):
# (0, 2, 0, 1., 12, 1, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 121
# =====================================
# ii = 122
# =====================================
# ii = 123
# =====================================
# ii = 124
# =====================================
# ii = 125
# =====================================
# ii = 126
# =====================================
# ii = 127
# =====================================
# ii = 128
# =====================================
# ii = 129
# =====================================
# ii = 130
# =====================================
# ii = 131
# =====================================
# ii = 132
# =====================================
# ii = 133
# =====================================
# ii = 134
# =====================================
# ii = 135
# =====================================
# ii = 136
# =====================================
# ii = 137
# =====================================
# ii = 138
# =====================================
# ii = 139
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 2, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 140
# =====================================
# ii = 141
# =====================================
# ii = 142
# =====================================
# ii = 143
# =====================================
# ii = 144
# =====================================
# ii = 145
# =====================================
# ii = 146
#
# Instance (of class *low*):
# (0, 2, 2, 4., 14, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 147
# =====================================
# ii = 148
# =====================================
# ii = 149
# =====================================
# ii = 150
# =====================================
# ii = 151
# =====================================
# ii = 152
# =====================================
# ii = 153
# =====================================
# ii = 154
# =====================================
# ii = 155
# =====================================
# ii = 156
# =====================================
# ii = 157
# =====================================
# ii = 158
# =====================================
# ii = 159
# =====================================
# ii = 160
#
# Instance (of class *low*):
# (0, 2, 1, 3., 14, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *1* -> *0*
# =====================================
# ii = 161
# =====================================
# ii = 162
# =====================================
# ii = 163
# =====================================
# ii = 164
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 165
# =====================================
# ii = 166
# =====================================
# ii = 167
#
# Instance (of class *high*):
# (0, 2, 0, 4., 11, 7, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 168
#
# Instance (of class *high*):
# (0, 2, 0, 3., 14, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 169
# =====================================
# ii = 170
# =====================================
# ii = 171
# =====================================
# ii = 172
# =====================================
# ii = 173
# =====================================
# ii = 174
#
# Instance (of class *low*):
# (0, 2, 0, 4., 12, 10, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 175
#
# Instance (of class *low*):
# (0, 2, 0, 4., 3, 1, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 176
# =====================================
# ii = 177
# =====================================
# ii = 178
# =====================================
# ii = 179
# =====================================
# ii = 180
# =====================================
# ii = 181
#
# Instance (of class *low*):
# (0, 2, 0, 4., 12, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 182
# =====================================
# ii = 183
# =====================================
# ii = 184
# =====================================
# ii = 185
# =====================================
# ii = 186
# =====================================
# ii = 187
# =====================================
# ii = 188
# =====================================
# ii = 189
# =====================================
# ii = 190
# =====================================
# ii = 191
# =====================================
# ii = 192
# =====================================
# ii = 193
# =====================================
# ii = 194
# =====================================
# ii = 195
# =====================================
# ii = 196
# =====================================
# ii = 197
#
# Instance (of class *high*):
# (0, 2, 2, 3., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
# =====================================
# ii = 198
# =====================================
# ii = 199
# =====================================
# ii = 200
# =====================================
# ii = 201
# =====================================
# ii = 202
#
# Instance (of class *low*):
# (0, 2, 0, 2., 4, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 203
# =====================================
# ii = 204
# =====================================
# ii = 205
# =====================================
# ii = 206
# =====================================
# ii = 207
# =====================================
# ii = 208
#
# Instance (of class *high*):
# (0, 2, 0, 1., 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 209
# =====================================
# ii = 210
# =====================================
# ii = 211
# =====================================
# ii = 212
#
# Instance (of class *low*):
# (1, 2, 0, 3., 12, 1, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *gender_female*: *1* -> *0*
#     feature *age_cat*: *2* -> *0*
# =====================================
# ii = 213
# =====================================
# ii = 214
# =====================================
# ii = 215
# =====================================
# ii = 216
# =====================================
# ii = 217
# =====================================
# ii = 218
# =====================================
# ii = 219
# =====================================
# ii = 220
#
# Instance (of class *high*):
# (0, 2, 2, 3., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
# =====================================
# ii = 221
#
# Instance (of class *high*):
# (0, 2, 0, 3., 3, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
# =====================================
# ii = 222
# =====================================
# ii = 223
# =====================================
# ii = 224
# =====================================
# ii = 225
# =====================================
# ii = 226
# =====================================
# ii = 227
# =====================================
# ii = 228
#
# Instance (of class *high*):
# (1, 2, 2, 4., 14, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *gender_female*: *1* -> *0*
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 229
#
# Instance (of class *low*):
# (0, 2, 2, 3., 14, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
# =====================================
# ii = 230
#
# Instance (of class *low*):
# (0, 2, 0, 3., 14, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 231
# =====================================
# ii = 232
# =====================================
# ii = 233
# =====================================
# ii = 234
# =====================================
# ii = 235
# =====================================
# ii = 236
# =====================================
# ii = 237
# =====================================
# ii = 238
#
# Instance (of class *high*):
# (0, 2, 0, 2., 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
# =====================================
# ii = 239
# =====================================
# ii = 240
# =====================================
# ii = 241
# =====================================
# ii = 242
# =====================================
# ii = 243
# =====================================
# ii = 244
# =====================================
# ii = 245
#
# Instance (of class *low*):
# (0, 2, 2, 3., 12, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 4.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 246
# =====================================
# ii = 247
#
# Instance (of class *low*):
# (0, 2, 2, 4., 14, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 248
# =====================================
# ii = 249
# =====================================
# ii = 250
#
# Instance (of class *high*):
# (0, 2, 0, 3., 14, 6, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 251
#
# Instance (of class *high*):
# (0, 2, 0, 3., 7, 4, 5)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 252
# =====================================
# ii = 253
# =====================================
# ii = 254
# =====================================
# ii = 255
# =====================================
# ii = 256
# =====================================
# ii = 257
# =====================================
# ii = 258
# =====================================
# ii = 259
#
# Instance (of class *high*):
# (0, 2, 1, 1., 14, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 260
#
# Instance (of class *low*):
# (0, 2, 0, 1., 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 261
# =====================================
# ii = 262
# =====================================
# ii = 263
#
# Instance (of class *low*):
# (0, 2, 2, 3., 15, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 264
#
# Instance (of class *high*):
# (0, 2, 0, 0.5, 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 265
# =====================================
# ii = 266
# =====================================
# ii = 267
#
# Instance (of class *high*):
# (0, 2, 2, 0.5, 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
# =====================================
# ii = 268
# =====================================
# ii = 269
# =====================================
# ii = 270
# =====================================
# ii = 271
# =====================================
# ii = 272
# =====================================
# ii = 273
# =====================================
# ii = 274
# =====================================
# ii = 275
# =====================================
# ii = 276
# =====================================
# ii = 277
# =====================================
# ii = 278
# =====================================
# ii = 279
# =====================================
# ii = 280
#
# Instance (of class *low*):
# (0, 1, 0, 1., 12, 1, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 281
#
# Instance (of class *low*):
# (0, 2, 2, 2., 15, 0, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *race*: *2* -> *0*
# =====================================
# ii = 282
# =====================================
# ii = 283
# =====================================
# ii = 284
# =====================================
# ii = 285
#
# Instance (of class *high*):
# (0, 2, 2, 2., 15, 0, 1)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 286
# =====================================
# ii = 287
#
# Instance (of class *high*):
# (0, 2, 2, 3., 14, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 288
# =====================================
# ii = 289
#
# Instance (of class *high*):
# (0, 2, 2, 3., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
# =====================================
# ii = 290
#
# Instance (of class *low*):
# (0, 2, 2, 1., 15, 1, 4)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 291
# =====================================
# ii = 292
# =====================================
# ii = 293
# =====================================
# ii = 294
# =====================================
# ii = 295
# =====================================
# ii = 296
#
# Instance (of class *high*):
# (0, 2, 2, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 297
# =====================================
# ii = 298
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
# ...
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *1* -> *0*
# =====================================
# ii = 898
# =====================================
# ii = 899
#
# Instance (of class *low*):
# (0, 2, 2, 4., 12, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 900
# =====================================
# ii = 901
#
# Instance (of class *low*):
# (0, 2, 0, 3., 12, 3, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 902
# =====================================
# ii = 903
#
# Instance (of class *high*):
# (0, 2, 2, 1., 12, 5, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 904
# =====================================
# ii = 905
# =====================================
# ii = 906
#
# Instance (of class *high*):
# (0, 2, 2, 1., 10, 6, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 4.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 907
# =====================================
# ii = 908
#
# Instance (of class *high*):
# (0, 1, 0, 3., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
# =====================================
# ii = 909
#
# Instance (of class *high*):
# (0, 2, 1, 3., 14, 7, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 910
# =====================================
# ii = 911
# =====================================
# ii = 912
#
# Instance (of class *low*):
# (0, 1, 0, 3., 12, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
# =====================================
# ii = 913
# =====================================
# ii = 914
# =====================================
# ii = 915
# =====================================
# ii = 916
# =====================================
# ii = 917
# =====================================
# ii = 918
# =====================================
# ii = 919
# =====================================
# ii = 920
# =====================================
# ii = 921
# =====================================
# ii = 922
# =====================================
# ii = 923
# =====================================
# ii = 924
# =====================================
# ii = 925
# =====================================
# ii = 926
# =====================================
# ii = 927
# =====================================
# ii = 928
# =====================================
# ii = 929
# =====================================
# ii = 930
#
# Instance (of class *high*):
# (0, 1, 2, 3., 12, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
# =====================================
# ii = 931
# =====================================
# ii = 932
#
# Instance (of class *low*):
# (0, 2, 2, 3., 12, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 933
#
# Instance (of class *high*):
# (0, 1, 0, 3., 12, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
# =====================================
# ii = 934
# =====================================
# ii = 935
# =====================================
# ii = 936
#
# Instance (of class *high*):
# (0, 2, 0, 3., 7, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
# =====================================
# ii = 937
# =====================================
# ii = 938
# =====================================
# ii = 939
#
# Instance (of class *high*):
# (0, 2, 0, 1., 14, 5, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 940
# =====================================
# ii = 941
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 5, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 942
#
# Instance (of class *high*):
# (0, 1, 0, 1., 12, 1, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 943
# =====================================
# ii = 944
# =====================================
# ii = 945
# =====================================
# ii = 946
# =====================================
# ii = 947
# =====================================
# ii = 948
#
# Instance (of class *low*):
# (0, 2, 2, 0.5, 6, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 949
#
# Instance (of class *high*):
# (0, 2, 0, 4., 15, 11, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
#
# Counterfactual instance (of class *low*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *0* -> *1*
# =====================================
# ii = 950
# =====================================
# ii = 951
# =====================================
# ii = 952
#
# Instance (of class *low*):
# (0, 2, 0, 2., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 953
# =====================================
# ii = 954
# =====================================
# ii = 955
# =====================================
# ii = 956
#
# Instance (of class *low*):
# (0, 2, 2, 4., 14, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 957
#
# Instance (of class *low*):
# (0, 2, 0, 4., 12, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 958
# =====================================
# ii = 959
# =====================================
# ii = 960
# =====================================
# ii = 961
#
# Instance (of class *high*):
# (0, 2, 2, 1., 9, 3, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *age_cat*: *2* -> *0*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 962
# =====================================
# ii = 963
# =====================================
# ii = 964
# =====================================
# ii = 965
#
# Instance (of class *high*):
# (0, 1, 1, 3., 14, 4, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
# =====================================
# ii = 966
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 2, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 967
#
# Instance (of class *low*):
# (0, 1, 0, 4., 12, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 968
# =====================================
# ii = 969
# =====================================
# ii = 970
#
# Instance (of class *high*):
# (0, 2, 2, 1., 15, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
# =====================================
# ii = 971
# =====================================
# ii = 972
# =====================================
# ii = 973
#
# Instance (of class *high*):
# (0, 1, 0, 2., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
# =====================================
# ii = 974
# =====================================
# ii = 975
# =====================================
# ii = 976
#
# Instance (of class *low*):
# (0, 2, 2, 3., 12, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 977
# =====================================
# ii = 978
# =====================================
# ii = 979
# =====================================
# ii = 980
# =====================================
# ii = 981
# =====================================
# ii = 982
# =====================================
# ii = 983
# =====================================
# ii = 984
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 11, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 985
#
# Instance (of class *high*):
# (0, 2, 0, 4., 12, 8, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
# =====================================
# ii = 986
# =====================================
# ii = 987
#
# Instance (of class *low*):
# (0, 1, 0, 4., 12, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 988
# =====================================
# ii = 989
#
# Instance (of class *low*):
# (1, 2, 2, 0.5, 15, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *gender_female*: *1* -> *0*
#     feature *age_cat*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *1*
#     feature *race*: *2* -> *1*
#
# Counterfactual instance (of class *high*):
# Distance: 3.0
#     feature *gender_female*: *1* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 990
#
# Instance (of class *high*):
# (0, 1, 0, 3., 14, 2, 3)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 1.0
#     feature *race*: *0* -> *1*
# =====================================
# ii = 991
# =====================================
# ii = 992
#
# Instance (of class *high*):
# (0, 1, 1, 1., 12, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *age_cat*: *1* -> *0*
#
# Counterfactual instance (of class *low*):
# Distance: 1.0
#     feature *race*: *1* -> *0*
# =====================================
# ii = 993
# =====================================
# ii = 994
# =====================================
# ii = 995
# =====================================
# ii = 996
# =====================================
# ii = 997
#
# Instance (of class *high*):
# (0, 1, 2, 2., 15, 0, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 3.0
#     feature *age_cat*: *1* -> *0*
#     feature *race*: *2* -> *0*
# =====================================
# ii = 998
# =====================================
# ii = 999
#
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 1, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *high*):
# Distance: 2.0
#     feature *age_cat*: *2* -> *0*
# 301

# %%
ii
# Out:
# 999

# %%
ct
# Out:
# 301

# %%
cfs_text = fatf_cf.textualise_counterfactuals(
    data_point,
    cfs,
    instance_class=data_point_y,
    counterfactuals_distances=cfs_distances,
    counterfactuals_predictions=cfs_classes)
print('\n{}'.format(cfs_text))
# Out:
# Instance (of class *high*):
# (0, 2, 0, 4., 14, 18, 2)
#
# Feature names: ('gender_female', 'age_cat', 'race', 'off_1_prs_max', 'off_1_gs_max', 'prior_commits', 'ic_institut_adj')
#
# Counterfactual instance (of class *low*):
# Distance: 1.5
#     feature *age_cat*: *2* -> *1.5*
#     feature *race*: *0* -> *1.0*
#
# Counterfactual instance (of class *low*):
# Distance: 1.5
#     feature *race*: *0* -> *1.5*
#
# Counterfactual instance (of class *low*):
# Distance: 1.5
#     feature *gender_female*: *0* -> *0.5*
#     feature *race*: *0* -> *1.0*

# %%
# Out:
# (0, 2, 0, 4., 15, 2, 3)

# %%
# Out:
# 'high'

# %%
cfs
# Out:
# array([], shape=(0, 0), dtype=float64)

# %% [markdown]
# ### Train the model

# %%
X = data.drop("ic_custdy_level", axis=1)
Y = data["ic_custdy_level"]

data_array = X.values
ground_truth = Y.values

#rf = rf_models.BasicRFModel(X, Y)
#rf.fit()

from sklearn.ensemble import RandomForestClassifier

rf2 = RandomForestClassifier()
rf2.fit(data_array, ground_truth)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Fairness for a single point

# %%
# Select a data point to evaluate its counterfactual fairness
data_point_index = 4 + 2
data_point = X.iloc[data_point_index : data_point_index+1, :]
data_point_y = Y[data_point_index : data_point_index+1]


data_point.loc[X.index[data_point_index],'gender_female']

# Select a set of protected features
#protected_features = ['gender_female', 'race', 'age_cat']
protected_features = [0,1,2]

# Print out the protected features
assert protected_features, 'The protected features list cannot be empty.'

person = ' is' if len(protected_features) == 1 else 's are'
print('The following feature{} considered protected:'.format(person))
for feature_name in protected_features:
    print('    * "{}".'.format(feature_name))

# Print the instance
print('\nEvaluating counterfactual fairness of a data point (index {}) of '
      'class *{}* with the following features:'.format(data_point_index,
                                                       data_point_y.name))
for feature_name in data_point.columns.values.tolist():
    print('    * The feature *{}* has value: {}.'.format(
        feature_name, data_point.loc[X.index[data_point_index],feature_name]))
# Out:
# The following features are considered protected:
#     * "0".
#     * "1".
#     * "2".
#
# Evaluating counterfactual fairness of a data point (index 6) of class *ic_custdy_level* with the following features:
#     * The feature *gender_female* has value: 0.
#     * The feature *age_cat* has value: 0.
#     * The feature *race* has value: 0.
#     * The feature *off_1_prs_max* has value: 4.
#     * The feature *off_1_gs_max* has value: 14.
#     * The feature *prior_commits* has value: 2.
#     * The feature *ic_institut_adj* has value: 2.

# %%
cfs, cfs_distances, cfs_classes = fatf_pfm.counterfactual_fairness(
    instance=data_point.values,
    protected_feature_indices=protected_features,
    model=rf2,
    default_numerical_step_size=.5,
    dataset=data_array)
# Out:
# ---------------------------------------------------------------------------
# IncorrectShapeError                       Traceback (most recent call last)
# <ipython-input-23-1321e1a1ef8e> in <module>
# ----> 1 cfs, cfs_distances, cfs_classes = fatf_pfm.counterfactual_fairness(
#       2     instance=data_point.values,
#       3     protected_feature_indices=protected_features,
#       4     model=rf2,
#       5     default_numerical_step_size=.5,
#
# ~/anaconda2/envs/psapm/lib/python3.8/site-packages/fatf/fairness/predictions/measures.py in counterfactual_fairness(instance, protected_feature_indices, counterfactual_class, model, predictive_function, dataset, categorical_indices, numerical_indices, max_counterfactual_length, feature_ranges, distance_functions, step_sizes, default_numerical_step_size, normalise_distance)
#      96         default_numerical_step_size=default_numerical_step_size)
#      97
# ---> 98     counterfactuals, distances, predictions = cfex.explain_instance(
#      99         instance, counterfactual_class, normalise_distance)
#     100
#
# ~/anaconda2/envs/psapm/lib/python3.8/site-packages/fatf/transparency/predictions/counterfactuals.py in explain_instance(self, instance, counterfactual_class, normalise_distance)
#     773         # pylint: disable=too-many-locals,too-many-branches,too-many-statements
#     774         if not fuav.is_1d_like(instance):
# --> 775             raise IncorrectShapeError('The instance to be explained should be '
#     776                                       'a 1-dimensional numpy array or a row '
#     777                                       'of a structured array (numpy.void).')
#
# IncorrectShapeError: The instance to be explained should be a 1-dimensional numpy array or a row of a structured array (numpy.void).

# %%
np.array([1,2])
# Out:
# array([1, 2])

# %%
type(data_point.values)
# Out:
# numpy.ndarray

# %%
type(data_point.values)
# Out:
# numpy.ndarray
